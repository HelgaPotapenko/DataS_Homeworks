# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore', category=Warning)

# %%
RANDOM_STATE = 42
results = pd.DataFrame(columns = ['model', 'task', 'accuracy'])

# %%
data = pd.read_csv('csv4ml//winequality-red.csv', sep = ';')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
from sklearn.model_selection import train_test_split

y = data['quality'] #целевая переменная
X = data.drop(columns=['quality']) #все остальное

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=RANDOM_STATE)

print (len(X_train)/len(data), len(X_test)/len(data))
# Out:
# 0.699812382739212 0.300187617260788

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier 

gb_sklearn = GradientBoostingClassifier()
acc_sklearn = cross_val_score(gb_sklearn, X, y, scoring='accuracy').mean()

results.loc[0] = ['GradientBoostingClassifier', 'task4', acc_sklearn]
results
# Out:
#                         model   task  accuracy
# 0  GradientBoostingClassifier  task4  0.564091

# %%
# %%time
from sklearn.metrics import accuracy_score

from sklearn.model_selection import GridSearchCV

learning_rates = np.arange(1.0, 2.0, 0.2)
trees_counts = [20, 50, 100, 150, 200,250]
trees_depth = range(3, 10)

params = {'learning_rate':learning_rates, 'n_estimators':trees_counts, 'max_depth':trees_depth} 
gb_sklearn_cv = GridSearchCV(GradientBoostingClassifier(), params, cv=3)
gb_sklearn_cv.fit(X_train, y_train)
y_pred = gb_sklearn_cv.predict(X_test)
acc_sklearn_cv = accuracy_score(y_test, y_pred)

best_params_sklearn = gb_sklearn_cv.best_params_
print('Параметры лучшей модели sklearn:\n', best_params_sklearn)

results.loc[1] = ['GradientBoostingClassifier_CV', 'task5', acc_sklearn_cv]
results
# Out:
# Параметры лучшей модели sklearn:
#  {'learning_rate': 1.0, 'max_depth': 7, 'n_estimators': 150}
# Wall time: 18min 21s
#                            model   task  accuracy
# 0     GradientBoostingClassifier  task4  0.564091
# 1  GradientBoostingClassifier_CV  task5  0.647917
# 2     GradientBoostingClassifier  task4  0.560349
# 4     GradientBoostingClassifier  task4  0.550361

# %%
gb_sklearn = GradientBoostingClassifier()
acc_sklearn = cross_val_score(gb_sklearn, X, y, scoring='accuracy').mean()

results.loc[2] = ['GradientBoostingClassifier', 'task4', acc_sklearn]
results
# Out:
#                            model   task  accuracy
# 0     GradientBoostingClassifier  task4  0.564091
# 1  GradientBoostingClassifier_CV  task5  0.614583
# 2     GradientBoostingClassifier  task4  0.560349

# %%
gb_sklearn = GradientBoostingClassifier(learning_rate=0.31, max_depth=9, n_estimators=150)
acc_sklearn = cross_val_score(gb_sklearn, X, y, scoring='accuracy').mean()

results.loc[4] = ['GradientBoostingClassifier', 'task4', acc_sklearn]
results
# Out:
#                            model   task  accuracy
# 0     GradientBoostingClassifier  task4  0.564091
# 1  GradientBoostingClassifier_CV  task5  0.643750
# 2     GradientBoostingClassifier  task4  0.560349
# 4     GradientBoostingClassifier  task4  0.550361
